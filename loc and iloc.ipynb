# %%
import pandas as pd
import random

# %%
data = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.shape[0]
# Out:
# 500

# %%
data.shape
# Out:
# (500, 11)

# %%
data['Id'] = [random.randint(0,1000) for x in range(data.shape[0])]

# %%
data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.iloc[0] #return first row
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Id                                               675
# Name: 0, dtype: object

# %%
data.iloc[1] #return second row
# Out:
# first_name                                   Evan
# last_name                               Zigomalas
# company_name                   Cap Gemini America
# address                               5 Binney St
# city                                   Abbey Ward
# county                            Buckinghamshire
# postal                                   HP11 2AX
# phone1                               01937-864715
# phone2                               01714-737668
# email                    evan.zigomalas@gmail.com
# web             http://www.capgeminiamerica.co.uk
# Id                                            244
# Name: 1, dtype: object

# %%
data.iloc[-1] #return last row
# Out:
# first_name                                               Mi
# last_name                                            Richan
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# Id                                                      121
# Name: 499, dtype: object

# %%
data.iloc[:,0] #first column
# Out:
# 0          Aleshia
# 1             Evan
# 2           France
# 3          Ulysses
# 4           Tyisha
# 5             Eric
# 6             Marg
# 7          Laquita
# 8             Lura
# 9           Yuette
# 10        Fernanda
# 11     Charlesetta
# 12        Corrinne
# 13          Niesha
# 14          Rueben
# 15         Michell
# 16           Edgar
# 17          Dewitt
# 18        Charisse
# 19             Mee
# 20           Peter
# 21         Octavio
# 22          Martha
# 23         Tamesha
# 24            Tess
# 25         Leonard
# 26        Svetlana
# 27             Pok
# 28       Augustine
# 29           Karma
#           ...
# 470           Tony
# 471            Val
# 472            Mel
# 473       Isabella
# 474         Erasmo
# 475          Ivory
# 476         Nikita
# 477          Aleta
# 478           Owen
# 479        Pauline
# 480        Tijuana
# 481          Ahmad
# 482         Jamika
# 483        Derrick
# 484     Jacquelyne
# 485        Zachary
# ...

# %%
data.iloc[:,1] #return second column
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
# 5           Rampy
# 6        Grasmick
# 7           Hisaw
# 8        Manzella
# 9          Klapec
# 10         Writer
# 11            Erm
# 12          Jaret
# 13          Bruch
# 14      Gastellum
# 15      Throssell
# 16          Kanne
# 17          Julio
# 18       Spinello
# 19       Lapinski
# 20      Gutierres
# 21      Salvadore
# 22        Teplica
# 23         Veigel
# 24          Sitra
# 25         Kufner
# 26         Tauras
# 27       Molaison
# 28       Growcock
# 29         Quarto
#           ...
# 470    Diazdeleon
# 471        Villot
# 472      Picciuto
# 473    Piatkowski
# 474          Rhea
# 475       Lohrenz
# 476         Walka
# 477        Ligons
# 478       Jentzen
# 479         Fling
# 480      Machalek
# 481       Alsaqri
# 482        Conoly
# 483       Dolloff
# 484       Reibman
# 485    Freeburger
# 486       Gaucher
# 487          Kono
# 488       Brigman
# ...

# %%
data.iloc[:,-1] #return last column
# Out:
# 0      675
# 1      244
# 2      321
# 3      552
# 4       87
# 5      450
# 6      416
# 7      364
# 8       33
# 9      269
# 10     469
# 11     774
# 12     661
# 13     600
# 14     806
# 15     534
# 16     525
# 17     112
# 18     960
# 19     398
# 20     910
# 21     633
# 22     194
# 23     385
# 24     383
# 25     766
# 26     917
# 27     264
# 28     751
# 29     966
#       ...
# 470    881
# 471    151
# 472    312
# 473    424
# 474    180
# 475    973
# 476    936
# 477    503
# 478    575
# 479    544
# 480    388
# 481    765
# 482    150
# 483     26
# 484    590
# 485    849
# 486    371
# 487    225
# 488    728
# 489     83
# 490    484
# 491    487
# 492    349
# 493    551
# 494    627
# 495    316
# 496    356
# 497    835
# 498    677
# 499    121
# Name: Id, Length: 500, dtype: int64

# %%
data.iloc[0,5] #first row of 5th column i.e. County
# Out:
# 'Kent'

# %%
data.iloc[1,6] #second row of 6th column i.e. Postal
# Out:
# 'HP11 2AX'

# %%
data.iloc[:, 1:5]
# Out:
#       last_name                    company_name                 address  \
# 0    Tomkiewicz         Alan D Rosenburg Cpa Pc            14 Taylor St
# 1     Zigomalas              Cap Gemini America             5 Binney St
# 2       Andrade             Elliott, John W Esq            8 Moor Place
# 3     Mcwalters                  Mcmahan, Ben L           505 Exeter Rd
# 4        Veness                  Champagne Room       5396 Forth Street
# 5         Rampy         Thompson, Michael C Esq            9472 Lind St
# 6      Grasmick   Wrangle Hill Auto Auct & Slvg        7457 Cowl St #70
# 7         Hisaw           In Communications Inc    20 Gloucester Pl #96
# 8      Manzella                 Bizerba Usa Inc        929 Augustine St
# 9        Klapec                       Max Video    45 Bradfield St #166
# 10       Writer            K & R Associates Inc      620 Northampton St
# 11          Erm                Cain, John M Esq             5 Hygeia St
# ...

# %%
data.iloc[-2:-1, -3:-1]
# Out:
#                          email                                     web
# 498  celestina_keeny@gmail.com  http://www.bfgfederalcreditunion.co.uk

# %%
data.set_index("last_name", inplace=True)

# %%
data.head(5)
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.loc[['Andrade', 'Veness']]
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web   Id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  321
# Veness       http://www.champagneroom.co.uk   87

# %%
data.loc[['Andrade', 'Veness'], ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
data.loc[data['first_name']=='Erasmo', ['company_name','email','phone1']]
# Out:
#                  company_name                         email        phone1
# last_name
# Talentino  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# Gath                 Pan Optx             egath@hotmail.com  01445-796544
# Rhea         Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397

# %%
data.loc[data['first_name']=='Antonio', 'email']
# Out:
# last_name
# Villamarin       antonio.villamarin@gmail.com
# Glasford      antonio_glasford@glasford.co.uk
# Heilig               antonio.heilig@gmail.com
# Name: email, dtype: object

# %%
data.loc[data['first_name']=='Antonio', ['email']]
# Out:
#                                       email
# last_name
# Villamarin     antonio.villamarin@gmail.com
# Glasford    antonio_glasford@glasford.co.uk
# Heilig             antonio.heilig@gmail.com

# %%
data.ix[['Andrade']] == data.loc[['Andrade']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#            first_name  company_name  address  city  county  postal  phone1  \
# last_name
# Andrade          True          True     True  True    True    True    True
#
#            phone2  email   web    Id
# last_name
# Andrade      True   True  True  True

# %%
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Tomkiewicz to Richan
# Data columns (total 11 columns):
# first_name      500 non-null object
# company_name    500 non-null object
# address         500 non-null object
# city            500 non-null object
# county          500 non-null object
# postal          500 non-null object
# phone1          500 non-null object
# phone2          500 non-null object
# email           500 non-null object
# web             500 non-null object
# Id              500 non-null int64
# dtypes: int64(1), object(10)
# memory usage: 66.9+ KB

# %%
categorical = [var for var in data.columns if data[var].dtype=='O']

# %%
print(categorical)
# Out:
# ['first_name', 'company_name', 'address', 'city', 'county', 'postal', 'phone1', 'phone2', 'email', 'web']

# %%
numerical = [var for var in data.columns if data[var].dtype!='O']

# %%
print(numerical)
# Out:
# ['Id']
